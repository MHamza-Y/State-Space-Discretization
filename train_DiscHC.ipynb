# %%
import torch
from torch.utils.data import DataLoader
from state_quantization.dataset import load_dataset
from state_quantization.dataset import DynamicsModelDataset
from state_quantization.quantization_models import ForcastingDiscHC, ForcastingDiscHCConst
from state_quantization.train import train_model, test_step
from state_quantization.eval import eval_model, compare_models
from state_quantization.trainer import NNTrainer
from torch.optim.lr_scheduler import MultiStepLR

# %%
use_cuda = torch.cuda.is_available()
device = torch.device("cuda:0" if use_cuda else "cpu")
print(f"Using Device: {device}")
torch.backends.cudnn.benchmark = True
# Out:
# Using Device: cuda:0

# %%
# parameters

bits = 20
use_cuda = torch.cuda.is_available()
model_path = f'tmp/state_quantization/model_h_c-{bits}bits6'
untrained_model_path = f'tmp/state_quantization/untrained_model_h_c-{bits}bits'
model_dict_path = 'tmp/state_quantization/model_h_c_dict'
log_dir = 'runs'

# %% [markdown]
# ## Load Dataset

# %%
dataset_input_key = 'merged_input'
dataset_output_key = 'merged_output'
dataset_file_path = 'tmp/ib-out/ib-samples-la.npy'
normalized_data_params_save_path = 'tmp/transformer/NormalizeInputConfigs.pkl'
dataset_device = 'cpu'
y_indexes = [4, 6]

train_dataset, val_dataset = load_dataset(file_path=dataset_file_path, input_key=dataset_input_key,
                                          output_key=dataset_output_key, dataset_class=DynamicsModelDataset,
                                          normalize=True, device=dataset_device, y_clip_range=y_indexes,
                                          normalized_input_data_params_save_path=normalized_data_params_save_path)

batch_size = 8000
params = {'batch_size': batch_size,
          'shuffle': True,
          'num_workers': 0,
          'drop_last': True,
          'pin_memory': not train_dataset.x.is_cuda}
print(params)
train_loader = DataLoader(train_dataset, **params)
val_loader = DataLoader(val_dataset, **params)
train_dataset.y[0]
# Out:
# Clipping y
# torch.Size([672000, 39, 6])
# torch.Size([672000, 10, 2])
# torch.Size([288000, 39, 6])
# torch.Size([288000, 10, 2])
# {'batch_size': 8000, 'shuffle': True, 'num_workers': 0, 'drop_last': True, 'pin_memory': True}
# tensor([[-0.4297, -0.6245],
#         [-0.3477, -0.5816],
#         [-0.2434, -0.5285],
#         [-0.2454, -0.5354],
#         [-0.3465, -0.5206],
#         [-0.6639, -0.5617],
#         [-0.6388, -0.5749],
#         [-0.8440, -0.5236],
#         [-1.0093, -0.4921],
#         [-1.0309, -0.4771]])

# %% [markdown]
# ## Define model

# %%
num_of_features = train_dataset.get_features_size()
seq_len = train_dataset.get_seq_len()
hidden_size = bits

out_size = train_dataset.get_output_feature_size()
print(f'Out Size:{out_size}')
look_ahead = train_dataset.get_look_ahead_size()
n_layers = 1
dropout_p = 0.1
print(look_ahead)
model = ForcastingDiscHC(features=num_of_features, hidden_size=hidden_size, out_size=out_size, seq_len=seq_len,
                               n_layers=n_layers, dropout=dropout_p,
                               look_ahead=look_ahead).to(device=device)
torch.save(model, untrained_model_path)

load_to_gpu = model.is_cuda() and not train_dataset.x.is_cuda
print(load_to_gpu)
# Out:
# Out Size:2
# 9
# LSTM Layers
# ModuleList(
#   (0): LSTMCell(6, 20)
# )
# LSTM Dropout Layers
# ModuleList()
# Fully Connected Layers
# Sequential(
#   (0): Linear(in_features=20, out_features=20, bias=True)
#   (1): GELU(approximate=none)
#   (2): Dropout(p=0.1, inplace=False)
#   (3): Linear(in_features=20, out_features=20, bias=True)
#   (4): GELU(approximate=none)
#   (5): Dropout(p=0.1, inplace=False)
#   (6): Linear(in_features=20, out_features=2, bias=True)
# )
# True

# %% [markdown]
# ## Train Model

# %%
lr = 1e-3
#lr_milestones=[4, 9]
lr_milestones=[24, 54]
gamma = 0.1

optimizer = torch.optim.Adam(model.parameters(), lr=lr)
lr_scheduler = MultiStepLR(optimizer, milestones=lr_milestones, gamma=gamma)
trainer = NNTrainer(model=model,train_loader=train_loader, test_loader=val_loader,load_to_gpu=load_to_gpu,optimizer=optimizer, lr_scheduler=lr_scheduler, train_loss_graph_tags=['Forecasting/train/loss'], eval_loss_graph_tags=['Forecasting/Eval/loss', 'Model/Eval/loss'],log_dir=log_dir)

# %%
trainer.train(n_epochs=50)
# Out:
# Untrained test
# --------
# --------------------------------------
# Model Test loss: 1.0312071508831449
# --------------------------------------
# --------------------------------------
# Epoch 1
# ---------
# --------------------------------------
# Model Train loss: 0.7734459578281357
# --------------------------------------
# Model Test loss: 0.4384531122114923
# --------------------------------------
# lr: [0.001]
# Epoch time: epoch_time = 9.405s
# --------------------------------------
# --------------------------------------
# Epoch 2
# ---------
# --------------------------------------
# Model Train loss: 0.317501788692815
# --------------------------------------
# Model Test loss: 0.2082855258550909
# --------------------------------------
# lr: [0.001]
# Epoch time: epoch_time = 9.464s
# --------------------------------------
# --------------------------------------
# Epoch 3
# ---------
# --------------------------------------
# Model Train loss: 0.20099701767876035
# --------------------------------------
# Model Test loss: 0.1477847629123264
# --------------------------------------
# lr: [0.001]
# Epoch time: epoch_time = 9.179s
# --------------------------------------
# --------------------------------------
# Epoch 4
# ---------
# --------------------------------------
# Model Train loss: 0.167092118589651
# --------------------------------------
# Model Test loss: 0.13620075376497376
# --------------------------------------
# lr: [0.001]
# Epoch time: epoch_time = 9.619s
# --------------------------------------
# --------------------------------------
# Epoch 5
# ---------
# --------------------------------------
# Model Train loss: 0.15905356442644483
# --------------------------------------
# Model Test loss: 0.1306778821680281
# --------------------------------------
# lr: [0.001]
# Epoch time: epoch_time = 9.501s
# --------------------------------------
# --------------------------------------
# Epoch 6
# ---------
# --------------------------------------
# Model Train loss: 0.1489152924290725
# --------------------------------------
# Model Test loss: 0.12167649219433467
# --------------------------------------
# lr: [0.001]
# Epoch time: epoch_time = 9.672s
# --------------------------------------
# --------------------------------------
# Epoch 7
# ---------
# --------------------------------------
# Model Train loss: 0.14362986456780208
# --------------------------------------
# Model Test loss: 0.11965373448199695
# --------------------------------------
# lr: [0.001]
# Epoch time: epoch_time = 9.547s
# --------------------------------------
# --------------------------------------
# Epoch 8
# ---------
# --------------------------------------
# Model Train loss: 0.14021582901477814
# --------------------------------------
# Model Test loss: 0.11504653344551723
# --------------------------------------
# lr: [0.001]
# Epoch time: epoch_time = 9.591s
# --------------------------------------
# --------------------------------------
# Epoch 9
# ---------
# --------------------------------------
# Model Train loss: 0.13599823131447747
# --------------------------------------
# Model Test loss: 0.11191391324003537
# --------------------------------------
# lr: [0.001]
# Epoch time: epoch_time = 9.584s
# --------------------------------------
# --------------------------------------
# Epoch 10
# ---------
# --------------------------------------
# Model Train loss: 0.1314176410614025
# --------------------------------------
# Model Test loss: 0.1083764440069596
# --------------------------------------
# lr: [0.001]
# Epoch time: epoch_time = 9.511s
# --------------------------------------
# --------------------------------------
# Epoch 11
# ---------
# --------------------------------------
# Model Train loss: 0.12963102669233367
# --------------------------------------
# Model Test loss: 0.1065361365262005
# --------------------------------------
# lr: [0.001]
# Epoch time: epoch_time = 9.106s
# --------------------------------------
# --------------------------------------
# Epoch 12
# ---------
# --------------------------------------
# Model Train loss: 0.12862237081641242
# --------------------------------------
# Model Test loss: 0.10828932747244835
# --------------------------------------
# lr: [0.001]
# Epoch time: epoch_time = 9.334s
# --------------------------------------
# --------------------------------------
# Epoch 13
# ---------
# --------------------------------------
# Model Train loss: 0.1289462744302693
# --------------------------------------
# Model Test loss: 0.10690089956753784
# --------------------------------------
# lr: [0.001]
# Epoch time: epoch_time = 9.448s
# --------------------------------------
# --------------------------------------
# Epoch 14
# ---------
# --------------------------------------
# Model Train loss: 0.12857955587761744
# --------------------------------------
# Model Test loss: 0.10692774525119199
# --------------------------------------
# lr: [0.001]
# Epoch time: epoch_time = 9.801s
# --------------------------------------
# --------------------------------------
# Epoch 15
# ---------
# --------------------------------------
# Model Train loss: 0.12815796388756662
# --------------------------------------
# Model Test loss: 0.10641644605331951
# --------------------------------------
# lr: [0.001]
# Epoch time: epoch_time = 9.166s
# --------------------------------------
# --------------------------------------
# Epoch 16
# ---------
# --------------------------------------
# Model Train loss: 0.12776861818773405
# --------------------------------------
# Model Test loss: 0.10514724151127869
# --------------------------------------
# lr: [0.001]
# Epoch time: epoch_time = 9.145s
# --------------------------------------
# --------------------------------------
# Epoch 17
# ---------
# --------------------------------------
# Model Train loss: 0.1274355405143329
# --------------------------------------
# Model Test loss: 0.10588787185649078
# --------------------------------------
# lr: [0.001]
# Epoch time: epoch_time = 9.238s
# --------------------------------------
# --------------------------------------
# Epoch 18
# ---------
# --------------------------------------
# Model Train loss: 0.1276033315807581
# --------------------------------------
# Model Test loss: 0.10453069789542092
# --------------------------------------
# lr: [0.001]
# Epoch time: epoch_time = 9.429s
# --------------------------------------
# --------------------------------------
# Epoch 19
# ---------
# --------------------------------------
# Model Train loss: 0.12563957176392987
# --------------------------------------
# Model Test loss: 0.10338517009384102
# --------------------------------------
# lr: [0.001]
# Epoch time: epoch_time = 9.050s
# --------------------------------------
# --------------------------------------
# Epoch 20
# ---------
# --------------------------------------
# Model Train loss: 0.12418384051748685
# --------------------------------------
# Model Test loss: 0.10251694483061631
# --------------------------------------
# lr: [0.001]
# Epoch time: epoch_time = 9.158s
# --------------------------------------
# --------------------------------------
# Epoch 21
# ---------
# --------------------------------------
# Model Train loss: 0.12190822467562698
# --------------------------------------
# Model Test loss: 0.09929135338299805
# --------------------------------------
# lr: [0.001]
# Epoch time: epoch_time = 9.077s
# --------------------------------------
# --------------------------------------
# Epoch 22
# ---------
# --------------------------------------
# Model Train loss: 0.11892708745740709
# --------------------------------------
# Model Test loss: 0.09654698086281617
# --------------------------------------
# lr: [0.001]
# Epoch time: epoch_time = 9.057s
# --------------------------------------
# --------------------------------------
# Epoch 23
# ---------
# --------------------------------------
# Model Train loss: 0.11633308107654254
# --------------------------------------
# Model Test loss: 0.09458465211921269
# --------------------------------------
# lr: [0.001]
# Epoch time: epoch_time = 8.934s
# --------------------------------------
# --------------------------------------
# Epoch 24
# ---------
# --------------------------------------
# Model Train loss: 0.11492797324345225
# --------------------------------------
# Model Test loss: 0.09274967180358039
# --------------------------------------
# lr: [0.001]
# Epoch time: epoch_time = 9.080s
# --------------------------------------
# --------------------------------------
# Epoch 25
# ---------
# --------------------------------------
# Model Train loss: 0.11373833566904068
# --------------------------------------
# Model Test loss: 0.09266472235321999
# --------------------------------------
# lr: [0.0001]
# Epoch time: epoch_time = 9.006s
# --------------------------------------
# --------------------------------------
# Epoch 26
# ---------
# --------------------------------------
# Model Train loss: 0.11352932568462122
# --------------------------------------
# Model Test loss: 0.0928968321532011
# --------------------------------------
# lr: [0.0001]
# Epoch time: epoch_time = 8.985s
# --------------------------------------
# --------------------------------------
# Epoch 27
# ---------
# --------------------------------------
# Model Train loss: 0.11379977085051082
# --------------------------------------
# Model Test loss: 0.09279258197380437
# --------------------------------------
# lr: [0.0001]
# Epoch time: epoch_time = 8.944s
# --------------------------------------
# --------------------------------------
# Epoch 28
# ---------
# --------------------------------------
# Model Train loss: 0.1137217041105032
# --------------------------------------
# Model Test loss: 0.09292951515979236
# --------------------------------------
# lr: [0.0001]
# Epoch time: epoch_time = 8.951s
# --------------------------------------
# --------------------------------------
# Epoch 29
# ---------
# --------------------------------------
# Model Train loss: 0.11354359141772702
# --------------------------------------
# Model Test loss: 0.09296858538356093
# --------------------------------------
# lr: [0.0001]
# Epoch time: epoch_time = 8.979s
# --------------------------------------
# --------------------------------------
# Epoch 30
# ---------
# --------------------------------------
# Model Train loss: 0.1134570265809695
# --------------------------------------
# Model Test loss: 0.09275161019629902
# --------------------------------------
# lr: [0.0001]
# Epoch time: epoch_time = 9.114s
# --------------------------------------
# --------------------------------------
# Epoch 31
# ---------
# --------------------------------------
# Model Train loss: 0.11349582796295483
# --------------------------------------
# Model Test loss: 0.09273481058577697
# --------------------------------------
# lr: [0.0001]
# Epoch time: epoch_time = 9.097s
# --------------------------------------
# --------------------------------------
# Epoch 32
# ---------
# --------------------------------------
# Model Train loss: 0.11376082444829601
# --------------------------------------
# Model Test loss: 0.09271825808617803
# --------------------------------------
# lr: [0.0001]
# Epoch time: epoch_time = 9.061s
# --------------------------------------
# --------------------------------------
# Epoch 33
# ---------
# --------------------------------------
# Model Train loss: 0.11368042833748318
# --------------------------------------
# Model Test loss: 0.09308216927780046
# --------------------------------------
# lr: [0.0001]
# Epoch time: epoch_time = 9.009s
# --------------------------------------
# --------------------------------------
# Epoch 34
# ---------
# --------------------------------------
# Model Train loss: 0.11365613483247303
# --------------------------------------
# Model Test loss: 0.09308762413760026
# --------------------------------------
# lr: [0.0001]
# Epoch time: epoch_time = 9.027s
# --------------------------------------
# --------------------------------------
# Epoch 35
# ---------
# --------------------------------------
# Model Train loss: 0.11380231052282311
# --------------------------------------
# Model Test loss: 0.09282153120471372
# --------------------------------------
# lr: [0.0001]
# Epoch time: epoch_time = 9.040s
# --------------------------------------
# --------------------------------------
# Epoch 36
# ---------
# --------------------------------------
# Model Train loss: 0.11365407111034506
# --------------------------------------
# Model Test loss: 0.09273989705575837
# --------------------------------------
# lr: [0.0001]
# Epoch time: epoch_time = 9.120s
# --------------------------------------
# --------------------------------------
# Epoch 37
# ---------
# --------------------------------------
# Model Train loss: 0.11387476688694387
# --------------------------------------
# Model Test loss: 0.09314966056909826
# --------------------------------------
# lr: [0.0001]
# Epoch time: epoch_time = 8.954s
# --------------------------------------
# --------------------------------------
# Epoch 38
# ---------
# --------------------------------------
# Model Train loss: 0.1138840356752986
# --------------------------------------
# Model Test loss: 0.09266171687179142
# --------------------------------------
# lr: [0.0001]
# Epoch time: epoch_time = 9.074s
# --------------------------------------
# --------------------------------------
# Epoch 39
# ---------
# --------------------------------------
# Model Train loss: 0.11379248861755643
# --------------------------------------
# Model Test loss: 0.09303618450131682
# --------------------------------------
# lr: [0.0001]
# Epoch time: epoch_time = 8.978s
# --------------------------------------
# --------------------------------------
# Epoch 40
# ---------
# --------------------------------------
# Model Train loss: 0.11354328221863225
# --------------------------------------
# Model Test loss: 0.09297311119735241
# --------------------------------------
# lr: [0.0001]
# Epoch time: epoch_time = 8.959s
# --------------------------------------
# --------------------------------------
# Epoch 41
# ---------
# --------------------------------------
# Model Train loss: 0.11385330735217958
# --------------------------------------
# Model Test loss: 0.092663891820444
# --------------------------------------
# lr: [0.0001]
# Epoch time: epoch_time = 8.928s
# --------------------------------------
# --------------------------------------
# Epoch 42
# ---------
# --------------------------------------
# Model Train loss: 0.11343757728380817
# --------------------------------------
# Model Test loss: 0.09251974978380734
# --------------------------------------
# lr: [0.0001]
# Epoch time: epoch_time = 8.851s
# --------------------------------------
# --------------------------------------
# Epoch 43
# ---------
# --------------------------------------
# Model Train loss: 0.11347590590871516
# --------------------------------------
# Model Test loss: 0.09290451059738795
# --------------------------------------
# lr: [0.0001]
# Epoch time: epoch_time = 9.018s
# --------------------------------------
# --------------------------------------
# Epoch 44
# ---------
# --------------------------------------
# Model Train loss: 0.11330734122367132
# --------------------------------------
# Model Test loss: 0.09256849251687527
# --------------------------------------
# lr: [0.0001]
# Epoch time: epoch_time = 8.924s
# --------------------------------------
# --------------------------------------
# Epoch 45
# ---------
# --------------------------------------
# Model Train loss: 0.113436550522844
# --------------------------------------
# Model Test loss: 0.09286595943073432
# --------------------------------------
# lr: [0.0001]
# Epoch time: epoch_time = 8.965s
# --------------------------------------
# --------------------------------------
# Epoch 46
# ---------
# --------------------------------------
# Model Train loss: 0.1135088253234114
# --------------------------------------
# Model Test loss: 0.09290778471363915
# --------------------------------------
# lr: [0.0001]
# Epoch time: epoch_time = 9.356s
# --------------------------------------
# --------------------------------------
# Epoch 47
# ---------
# --------------------------------------
# Model Train loss: 0.11306273165558066
# --------------------------------------
# Model Test loss: 0.09270144295361307
# --------------------------------------
# lr: [0.0001]
# Epoch time: epoch_time = 9.350s
# --------------------------------------
# --------------------------------------
# Epoch 48
# ---------
# --------------------------------------
# Model Train loss: 0.11299886864920457
# --------------------------------------
# Model Test loss: 0.09254218927688068
# --------------------------------------
# lr: [0.0001]
# Epoch time: epoch_time = 9.470s
# --------------------------------------
# --------------------------------------
# Epoch 49
# ---------
# --------------------------------------
# Model Train loss: 0.11320530232929048
# --------------------------------------
# Model Test loss: 0.09303356976144844
# --------------------------------------
# lr: [0.0001]
# Epoch time: epoch_time = 9.642s
# --------------------------------------
# --------------------------------------
# Epoch 50
# ---------
# --------------------------------------
# Model Train loss: 0.11353554762899876
# --------------------------------------
# Model Test loss: 0.0930902428097195
# --------------------------------------
# lr: [0.0001]
# Epoch time: epoch_time = 9.406s

# %% [markdown]
# ## Save Model

# %%
torch.save(model.state_dict(), model_dict_path)
torch.save(model, model_path)
torch.cuda.empty_cache()
del model

# %% [markdown]
# ## Load Model for evaluation

# %%
model_classes = [ForcastingDiscHC, ForcastingDiscHCConst]
models = []
for model_class in model_classes:
    models.append(model_class(features=num_of_features, hidden_size=hidden_size, out_size=out_size,
                              seq_len=seq_len, n_layers=n_layers, dropout=dropout_p,
                              look_ahead=look_ahead).to(device))
    models[-1].load_state_dict(torch.load(model_dict_path))
# Out:
# LSTM Layers
# ModuleList(
#   (0): LSTMCell(6, 20)
# )
# LSTM Dropout Layers
# ModuleList()
# Fully Connected Layers
# Sequential(
#   (0): Linear(in_features=20, out_features=20, bias=True)
#   (1): GELU(approximate=none)
#   (2): Dropout(p=0.1, inplace=False)
#   (3): Linear(in_features=20, out_features=20, bias=True)
#   (4): GELU(approximate=none)
#   (5): Dropout(p=0.1, inplace=False)
#   (6): Linear(in_features=20, out_features=2, bias=True)
# )
# LSTM Layers
# ModuleList(
#   (0): LSTMCell(6, 20)
# )
# LSTM Dropout Layers
# ModuleList()
# Fully Connected Layers
# Sequential(
#   (0): Linear(in_features=20, out_features=20, bias=True)
#   (1): GELU(approximate=none)
#   (2): Dropout(p=0.1, inplace=False)
#   (3): Linear(in_features=20, out_features=20, bias=True)
#   (4): GELU(approximate=none)
#   (5): Dropout(p=0.1, inplace=False)
#   (6): Linear(in_features=20, out_features=2, bias=True)
# )

# %%
for la_model in models:
    print(la_model.__class__.__name__)
    test_step(model=la_model, data_loader=val_loader, loss_function=torch.nn.MSELoss(), load_to_gpu=load_to_gpu)
# Out:
# ForcastingDiscHC
# Test loss: 0.0930902436375618
# ForcastingDiscHCConst
# Test loss: 0.15199581078357166

# %%
#value_keys = ['setpoint', 'velocity', 'gain', 'shift', 'fatigue', 'consumption']
value_keys = ['fatigue', 'consumption']

models = []
for model_class in model_classes:
    models.append(model_class(features=num_of_features, hidden_size=hidden_size, out_size=out_size,
                              seq_len=seq_len, n_layers=n_layers, dropout=dropout_p,
                              look_ahead=look_ahead).to(dataset_device))
    models[-1].load_state_dict(torch.load(model_dict_path))

compare_models(models[:1], x=val_dataset.x[87], y=val_dataset.y[87], value_keys=value_keys)
# Out:
# LSTM Layers
# ModuleList(
#   (0): LSTMCell(6, 20)
# )
# LSTM Dropout Layers
# ModuleList()
# Fully Connected Layers
# Sequential(
#   (0): Linear(in_features=20, out_features=20, bias=True)
#   (1): GELU(approximate=none)
#   (2): Dropout(p=0.1, inplace=False)
#   (3): Linear(in_features=20, out_features=20, bias=True)
#   (4): GELU(approximate=none)
#   (5): Dropout(p=0.1, inplace=False)
#   (6): Linear(in_features=20, out_features=2, bias=True)
# )
# LSTM Layers
# ModuleList(
#   (0): LSTMCell(6, 20)
# )
# LSTM Dropout Layers
# ModuleList()
# Fully Connected Layers
# Sequential(
#   (0): Linear(in_features=20, out_features=20, bias=True)
#   (1): GELU(approximate=none)
#   (2): Dropout(p=0.1, inplace=False)
#   (3): Linear(in_features=20, out_features=20, bias=True)
#   (4): GELU(approximate=none)
#   (5): Dropout(p=0.1, inplace=False)
#   (6): Linear(in_features=20, out_features=2, bias=True)
# )
