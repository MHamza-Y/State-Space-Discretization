# %%
import torch
from torch.utils.data import DataLoader
from state_quantization.dataset import load_dataset
from state_quantization.dataset import DynamicsModelDataset
from state_quantization.train import train_model, test_step
from state_quantization.eval import eval_model, compare_models
from state_quantization.forcasting_models import LSTMForcasting, LSTMForcastingConstOut
from state_quantization.trainer import NNTrainer
from torch.optim.lr_scheduler import MultiStepLR

# %%
use_cuda = torch.cuda.is_available()
device = torch.device("cuda:0" if use_cuda else "cpu")
print(f"Using Device: {device}")
torch.backends.cudnn.benchmark = True
# Out:
# Using Device: cuda:0

# %% [markdown]
# ## Load Dataset

# %%
dataset_input_key = 'merged_input'
dataset_output_key = 'merged_output'
dataset_file_path = 'tmp/ib-out/ib-samples-la.npy'
normalized_data_params_save_path = 'tmp/transformer/NormalizeInputConfigs.pkl'
dataset_device = 'cpu'
y_indexes = [4, 6]

train_dataset, val_dataset = load_dataset(file_path=dataset_file_path, input_key=dataset_input_key,
                                          output_key=dataset_output_key, dataset_class=DynamicsModelDataset,
                                          normalize=True, device=dataset_device, y_clip_range=y_indexes,
                                          normalized_input_data_params_save_path=normalized_data_params_save_path)

batch_size = 8000
params = {'batch_size': batch_size,
          'shuffle': True,
          'num_workers': 0,
          'drop_last': True,
          'pin_memory': not train_dataset.x.is_cuda}
print(params)
train_loader = DataLoader(train_dataset, **params)
val_loader = DataLoader(val_dataset, **params)
train_dataset.y[0]
# Out:
# Clipping y
# torch.Size([672000, 39, 6])
# torch.Size([672000, 10, 2])
# torch.Size([288000, 39, 6])
# torch.Size([288000, 10, 2])
# {'batch_size': 8000, 'shuffle': True, 'num_workers': 0, 'drop_last': True, 'pin_memory': True}
# tensor([[-0.8233,  0.3537],
#         [-0.6556,  0.2818],
#         [-0.8421,  0.2420],
#         [-0.8779,  0.2863],
#         [-0.6942,  0.2825],
#         [-0.8032,  0.2881],
#         [-0.7378,  0.2211],
#         [-0.6053,  0.1703],
#         [-0.4699,  0.1287],
#         [-0.5391,  0.1608]])

# %% [markdown]
# ## Define model

# %%
model_dict_path = 'state_quantization/model_no_disc_dict'
model_path = 'state_quantization/model_no_disc'
num_of_features = train_dataset.get_features_size()
seq_len = train_dataset.get_seq_len()
hidden_size = 20
out_size = train_dataset.get_output_feature_size()
print(f'Out Size:{out_size}')
look_ahead = train_dataset.get_look_ahead_size()
n_layers = 1
dropout = 0.1
print(look_ahead)
model = forcasting_model = LSTMForcasting(features=num_of_features, hidden_size=hidden_size, out_size=out_size, seq_len=seq_len,
                                  look_ahead=look_ahead, dropout=dropout, n_layers=n_layers).to(device=device)

load_to_gpu = model.is_cuda() and not train_dataset.x.is_cuda
print(load_to_gpu)
# Out:
# Out Size:2
# 9
# LSTM Layers
# ModuleList(
#   (0): LSTMCell(6, 20)
# )
# LSTM Dropout Layers
# ModuleList()
# Fully Connected Layers
# Sequential(
#   (0): Linear(in_features=20, out_features=20, bias=True)
#   (1): GELU(approximate=none)
#   (2): Dropout(p=0.1, inplace=False)
#   (3): Linear(in_features=20, out_features=20, bias=True)
#   (4): GELU(approximate=none)
#   (5): Dropout(p=0.1, inplace=False)
#   (6): Linear(in_features=20, out_features=2, bias=True)
# )
# True

# %% [markdown]
# ## Train Model

# %%
lr = 1e-3

lr_milestones=[24, 54]
gamma = 0.1

optimizer = torch.optim.Adam(model.parameters(), lr=lr)
lr_scheduler = MultiStepLR(optimizer, milestones=lr_milestones, gamma=gamma)
trainer = NNTrainer(model=model,train_loader=train_loader, test_loader=val_loader,load_to_gpu=load_to_gpu,optimizer=optimizer, lr_scheduler=lr_scheduler)

# %%
trainer.train(n_epochs=50)
# train_model(model=model, train_loader=train_loader, test_loader=val_loader, n_epochs=100, learning_rate=1e-3,
#             load_to_gpu=load_to_gpu, gamma=0.1, lr_milestones=[25, 200])
# Out:
# Untrained test
# --------
# --------------------------------------
# Model Test loss: 1.0279005186425314
# --------------------------------------
# --------------------------------------
# Epoch 1
# ---------
# --------------------------------------
# Model Train loss: 0.7831801176071167
# --------------------------------------
# Model Test loss: 0.3615417066547606
# --------------------------------------
# lr: [0.001]
# Epoch time: epoch_time = 8.980s
# --------------------------------------
# --------------------------------------
# Epoch 2
# ---------
# --------------------------------------
# Model Train loss: 0.19947873889690354
# --------------------------------------
# Model Test loss: 0.08821214963164595
# --------------------------------------
# lr: [0.001]
# Epoch time: epoch_time = 8.951s
# --------------------------------------
# --------------------------------------
# Epoch 3
# ---------
# --------------------------------------
# Model Train loss: 0.10570650982360046
# --------------------------------------
# Model Test loss: 0.06302970399459203
# --------------------------------------
# lr: [0.001]
# Epoch time: epoch_time = 9.097s
# --------------------------------------
# --------------------------------------
# Epoch 4
# ---------
# --------------------------------------
# Model Train loss: 0.08485854425955386
# --------------------------------------
# Model Test loss: 0.05070011897219552
# --------------------------------------
# lr: [0.001]
# Epoch time: epoch_time = 8.880s
# --------------------------------------
# --------------------------------------
# Epoch 5
# ---------
# --------------------------------------
# Model Train loss: 0.07444567641332037
# --------------------------------------
# Model Test loss: 0.04545443401568466
# --------------------------------------
# lr: [0.001]
# Epoch time: epoch_time = 8.536s
# --------------------------------------
# --------------------------------------
# Epoch 6
# ---------
# --------------------------------------
# Model Train loss: 0.06905618593806312
# --------------------------------------
# Model Test loss: 0.041815277809898056
# --------------------------------------
# lr: [0.001]
# Epoch time: epoch_time = 8.726s
# --------------------------------------
# --------------------------------------
# Epoch 7
# ---------
# --------------------------------------
# Model Train loss: 0.06503256915935449
# --------------------------------------
# Model Test loss: 0.039300868184202246
# --------------------------------------
# lr: [0.001]
# Epoch time: epoch_time = 8.679s
# --------------------------------------
# --------------------------------------
# Epoch 8
# ---------
# --------------------------------------
# Model Train loss: 0.062315549834498336
# --------------------------------------
# Model Test loss: 0.03801867241660754
# --------------------------------------
# lr: [0.001]
# Epoch time: epoch_time = 8.488s
# --------------------------------------
# --------------------------------------
# Epoch 9
# ---------
# --------------------------------------
# Model Train loss: 0.060400654739212425
# --------------------------------------
# Model Test loss: 0.037098049082689814
# --------------------------------------
# lr: [0.001]
# Epoch time: epoch_time = 8.738s
# --------------------------------------
# --------------------------------------
# Epoch 10
# ---------
# --------------------------------------
# Model Train loss: 0.05898028017864341
# --------------------------------------
# Model Test loss: 0.03582943406783872
# --------------------------------------
# lr: [0.001]
# Epoch time: epoch_time = 8.744s
# --------------------------------------
# --------------------------------------
# Epoch 11
# ---------
# --------------------------------------
# Model Train loss: 0.05785877111234835
# --------------------------------------
# Model Test loss: 0.03504280590762695
# --------------------------------------
# lr: [0.001]
# Epoch time: epoch_time = 8.653s
# --------------------------------------
# --------------------------------------
# Epoch 12
# ---------
# --------------------------------------
# Model Train loss: 0.05700855316328151
# --------------------------------------
# Model Test loss: 0.03491469472646713
# --------------------------------------
# lr: [0.001]
# Epoch time: epoch_time = 8.709s
# --------------------------------------
# --------------------------------------
# Epoch 13
# ---------
# --------------------------------------
# Model Train loss: 0.05611786042295751
# --------------------------------------
# Model Test loss: 0.034133069734606475
# --------------------------------------
# lr: [0.001]
# Epoch time: epoch_time = 8.808s
# --------------------------------------
# --------------------------------------
# Epoch 14
# ---------
# --------------------------------------
# Model Train loss: 0.055360011401630584
# --------------------------------------
# Model Test loss: 0.03311964910891321
# --------------------------------------
# lr: [0.001]
# Epoch time: epoch_time = 8.768s
# --------------------------------------
# --------------------------------------
# Epoch 15
# ---------
# --------------------------------------
# Model Train loss: 0.05481112154111976
# --------------------------------------
# Model Test loss: 0.033201432372960776
# --------------------------------------
# lr: [0.001]
# Epoch time: epoch_time = 8.614s
# --------------------------------------
# --------------------------------------
# Epoch 16
# ---------
# --------------------------------------
# Model Train loss: 0.05424281400406644
# --------------------------------------
# Model Test loss: 0.033145564504795604
# --------------------------------------
# lr: [0.001]
# Epoch time: epoch_time = 8.718s
# --------------------------------------
# --------------------------------------
# Epoch 17
# ---------
# --------------------------------------
# Model Train loss: 0.053802533430002984
# --------------------------------------
# Model Test loss: 0.03241407757418023
# --------------------------------------
# lr: [0.001]
# Epoch time: epoch_time = 8.684s
# --------------------------------------
# --------------------------------------
# Epoch 18
# ---------
# --------------------------------------
# Model Train loss: 0.05334848835177365
# --------------------------------------
# Model Test loss: 0.032510275900777846
# --------------------------------------
# lr: [0.001]
# Epoch time: epoch_time = 8.551s
# --------------------------------------
# --------------------------------------
# Epoch 19
# ---------
# --------------------------------------
# Model Train loss: 0.05301884393252078
# --------------------------------------
# Model Test loss: 0.03248141105804178
# --------------------------------------
# lr: [0.001]
# Epoch time: epoch_time = 8.566s
# --------------------------------------
# --------------------------------------
# Epoch 20
# ---------
# --------------------------------------
# Model Train loss: 0.05252198502421379
# --------------------------------------
# Model Test loss: 0.0316635196407636
# --------------------------------------
# lr: [0.001]
# Epoch time: epoch_time = 8.721s
# --------------------------------------
# --------------------------------------
# Epoch 21
# ---------
# --------------------------------------
# Model Train loss: 0.05212818884423801
# --------------------------------------
# Model Test loss: 0.03127383999526501
# --------------------------------------
# lr: [0.001]
# Epoch time: epoch_time = 8.597s
# --------------------------------------
# --------------------------------------
# Epoch 22
# ---------
# --------------------------------------
# Model Train loss: 0.051929477957032975
# --------------------------------------
# Model Test loss: 0.03221541581054529
# --------------------------------------
# lr: [0.001]
# Epoch time: epoch_time = 9.096s
# --------------------------------------
# --------------------------------------
# Epoch 23
# ---------
# --------------------------------------
# Model Train loss: 0.05152718155156998
# --------------------------------------
# Model Test loss: 0.031359206729878984
# --------------------------------------
# lr: [0.001]
# Epoch time: epoch_time = 9.113s
# --------------------------------------
# --------------------------------------
# Epoch 24
# ---------
# --------------------------------------
# Model Train loss: 0.05119534404504867
# --------------------------------------
# Model Test loss: 0.03071962943714526
# --------------------------------------
# lr: [0.001]
# Epoch time: epoch_time = 9.040s
# --------------------------------------
# --------------------------------------
# Epoch 25
# ---------
# --------------------------------------
# Model Train loss: 0.05079005951327937
# --------------------------------------
# Model Test loss: 0.030663808135108814
# --------------------------------------
# lr: [0.0001]
# Epoch time: epoch_time = 8.812s
# --------------------------------------
# --------------------------------------
# Epoch 26
# ---------
# --------------------------------------
# Model Train loss: 0.05070568071234794
# --------------------------------------
# Model Test loss: 0.030635761614474986
# --------------------------------------
# lr: [0.0001]
# Epoch time: epoch_time = 8.787s
# --------------------------------------
# --------------------------------------
# Epoch 27
# ---------
# --------------------------------------
# Model Train loss: 0.05069443667750983
# --------------------------------------
# Model Test loss: 0.030784935793942876
# --------------------------------------
# lr: [0.0001]
# Epoch time: epoch_time = 8.967s
# --------------------------------------
# --------------------------------------
# Epoch 28
# ---------
# --------------------------------------
# Model Train loss: 0.050757852249911854
# --------------------------------------
# Model Test loss: 0.030494445107049413
# --------------------------------------
# lr: [0.0001]
# Epoch time: epoch_time = 8.967s
# --------------------------------------
# --------------------------------------
# Epoch 29
# ---------
# --------------------------------------
# Model Train loss: 0.05071075331597101
# --------------------------------------
# Model Test loss: 0.030521866555015247
# --------------------------------------
# lr: [0.0001]
# Epoch time: epoch_time = 8.922s
# --------------------------------------
# --------------------------------------
# Epoch 30
# ---------
# --------------------------------------
# Model Train loss: 0.05069500411904994
# --------------------------------------
# Model Test loss: 0.030539297447022464
# --------------------------------------
# lr: [0.0001]
# Epoch time: epoch_time = 8.742s
# --------------------------------------
# --------------------------------------
# Epoch 31
# ---------
# --------------------------------------
# Model Train loss: 0.05060571693770942
# --------------------------------------
# Model Test loss: 0.030636328582962353
# --------------------------------------
# lr: [0.0001]
# Epoch time: epoch_time = 8.677s
# --------------------------------------
# --------------------------------------
# Epoch 32
# ---------
# --------------------------------------
# Model Train loss: 0.05057368768999974
# --------------------------------------
# Model Test loss: 0.03048168257292774
# --------------------------------------
# lr: [0.0001]
# Epoch time: epoch_time = 9.170s
# --------------------------------------
# --------------------------------------
# Epoch 33
# ---------
# --------------------------------------
# Model Train loss: 0.0505229134910873
# --------------------------------------
# Model Test loss: 0.030481329291231103
# --------------------------------------
# lr: [0.0001]
# Epoch time: epoch_time = 9.143s
# --------------------------------------
# --------------------------------------
# Epoch 34
# ---------
# --------------------------------------
# Model Train loss: 0.05043174472770521
# --------------------------------------
# Model Test loss: 0.030444334261119366
# --------------------------------------
# lr: [0.0001]
# Epoch time: epoch_time = 9.360s
# --------------------------------------
# --------------------------------------
# Epoch 35
# ---------
# --------------------------------------
# Model Train loss: 0.0503889751576242
# --------------------------------------
# Model Test loss: 0.03041596384719014
# --------------------------------------
# lr: [0.0001]
# Epoch time: epoch_time = 9.119s
# --------------------------------------
# --------------------------------------
# Epoch 36
# ---------
# --------------------------------------
# Model Train loss: 0.05038543493442592
# --------------------------------------
# Model Test loss: 0.03032339172851708
# --------------------------------------
# lr: [0.0001]
# Epoch time: epoch_time = 9.127s
# --------------------------------------
# --------------------------------------
# Epoch 37
# ---------
# --------------------------------------
# Model Train loss: 0.05035105409721533
# --------------------------------------
# Model Test loss: 0.030370297220846016
# --------------------------------------
# lr: [0.0001]
# Epoch time: epoch_time = 9.154s
# --------------------------------------
# --------------------------------------
# Epoch 38
# ---------
# --------------------------------------
# Model Train loss: 0.050337202447865693
# --------------------------------------
# Model Test loss: 0.030293259407497115
# --------------------------------------
# lr: [0.0001]
# Epoch time: epoch_time = 9.244s
# --------------------------------------
# --------------------------------------
# Epoch 39
# ---------
# --------------------------------------
# Model Train loss: 0.0502111663864482
# --------------------------------------
# Model Test loss: 0.030363771909226973
# --------------------------------------
# lr: [0.0001]
# Epoch time: epoch_time = 9.223s
# --------------------------------------
# --------------------------------------
# Epoch 40
# ---------
# --------------------------------------
# Model Train loss: 0.05016278657352641
# --------------------------------------
# Model Test loss: 0.03021770477708843
# --------------------------------------
# lr: [0.0001]
# Epoch time: epoch_time = 9.135s
# --------------------------------------
# --------------------------------------
# Epoch 41
# ---------
# --------------------------------------
# Model Train loss: 0.05009333727260431
# --------------------------------------
# Model Test loss: 0.030258742161095142
# --------------------------------------
# lr: [0.0001]
# Epoch time: epoch_time = 9.238s
# --------------------------------------
# --------------------------------------
# Epoch 42
# ---------
# --------------------------------------
# Model Train loss: 0.05010597869044259
# --------------------------------------
# Model Test loss: 0.030265417001727555
# --------------------------------------
# lr: [0.0001]
# Epoch time: epoch_time = 9.113s
# --------------------------------------
# --------------------------------------
# Epoch 43
# ---------
# --------------------------------------
# Model Train loss: 0.05000730954288017
# --------------------------------------
# Model Test loss: 0.030129175788412493
# --------------------------------------
# lr: [0.0001]
# Epoch time: epoch_time = 9.138s
# --------------------------------------
# --------------------------------------
# Epoch 44
# ---------
# --------------------------------------
# Model Train loss: 0.05000595739554791
# --------------------------------------
# Model Test loss: 0.029980732697165675
# --------------------------------------
# lr: [0.0001]
# Epoch time: epoch_time = 9.162s
# --------------------------------------
# --------------------------------------
# Epoch 45
# ---------
# --------------------------------------
# Model Train loss: 0.04993628475460268
# --------------------------------------
# Model Test loss: 0.030092537610067263
# --------------------------------------
# lr: [0.0001]
# Epoch time: epoch_time = 9.155s
# --------------------------------------
# --------------------------------------
# Epoch 46
# ---------
# --------------------------------------
# Model Train loss: 0.049862339826566834
# --------------------------------------
# Model Test loss: 0.029954718477610085
# --------------------------------------
# lr: [0.0001]
# Epoch time: epoch_time = 9.131s
# --------------------------------------
# --------------------------------------
# Epoch 47
# ---------
# --------------------------------------
# Model Train loss: 0.049860723671459016
# --------------------------------------
# Model Test loss: 0.02998809738912516
# --------------------------------------
# lr: [0.0001]
# Epoch time: epoch_time = 9.190s
# --------------------------------------
# --------------------------------------
# Epoch 48
# ---------
# --------------------------------------
# Model Train loss: 0.04974745245029529
# --------------------------------------
# Model Test loss: 0.029840758742971554
# --------------------------------------
# lr: [0.0001]
# Epoch time: epoch_time = 9.319s
# --------------------------------------
# --------------------------------------
# Epoch 49
# ---------
# --------------------------------------
# Model Train loss: 0.049740253060701345
# --------------------------------------
# Model Test loss: 0.029818517466386158
# --------------------------------------
# lr: [0.0001]
# Epoch time: epoch_time = 8.922s
# --------------------------------------
# --------------------------------------
# Epoch 50
# ---------
# --------------------------------------
# Model Train loss: 0.049680640610555805
# --------------------------------------
# Model Test loss: 0.029856005424840584
# --------------------------------------
# lr: [0.0001]
# Epoch time: epoch_time = 8.838s

# %% [markdown]
# ## Save Model

# %%
torch.save(model.state_dict(), model_dict_path)
#torch.save(model, model_path)
torch.cuda.empty_cache()
del model

# %% [markdown]
# ## Load Model for evaluation

# %%
model_classes = [LSTMForcasting, LSTMForcastingConstOut]
models = []
for model_class in model_classes:
    models.append(model_class(features=num_of_features, hidden_size=hidden_size, out_size=out_size,
                              seq_len=seq_len, n_layers=n_layers, dropout_p=dropout,
                              look_ahead=look_ahead).to(device))
    models[-1].load_state_dict(torch.load(model_dict_path))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [8], in <cell line: 3>()
#       2 models = []
#       3 for model_class in model_classes:
# ----> 4     models.append(model_class(features=num_of_features, hidden_size=hidden_size, out_size=out_size,
#       5                               seq_len=seq_len, n_layers=n_layers, dropout_p=dropout,
#       6                               look_ahead=look_ahead).to(device))
#       7     models[-1].load_state_dict(torch.load(model_dict_path))
#
# TypeError: __init__() got an unexpected keyword argument 'dropout_p'

# %%
for la_model in models:
    print(la_model.__class__.__name__)
    test_step(model=la_model, data_loader=val_loader, loss_function=torch.nn.MSELoss(), load_to_gpu=load_to_gpu)

# %%
#value_keys = ['setpoint', 'velocity', 'gain', 'shift', 'fatigue', 'consumption']
value_keys = ['fatigue', 'consumption']

models = []
for model_class in model_classes:
    models.append(model_class(features=num_of_features, hidden_size=hidden_size, out_size=out_size,
                              seq_len=seq_len, n_layers=n_layers, dropout_p=dropout,
                              look_ahead=look_ahead).to(dataset_device))
    models[-1].load_state_dict(torch.load(model_dict_path))

compare_models(models, x=val_dataset.x[78], y=val_dataset.y[78], value_keys=value_keys)
